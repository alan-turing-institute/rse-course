# %% [markdown]
# # Classroom exercise: energy calculation
#
# ## Diffusion model in 1D
#
# Description: A one-dimensional diffusion model. (Could be a gas of particles, or a bunch of crowded people in a corridor, or animals in a valley habitat...)
#
# - Agents are on a 1d axis
# - Agents do not want to be where there are other agents
# - This is represented as an 'energy': the higher the energy, the more unhappy the agents.
#
# Implementation:
#
# - Given a vector $n$ of positive integers, and of arbitrary length
# - Compute the energy, $E(n) = \sum_i n_i(n_i - 1)$
# - Later, we will have the likelyhood of an agent moving depend on the change in energy.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

density = np.array([0, 0, 3, 5, 8, 4, 2, 1])
fig, ax = plt.subplots()
ax.bar(np.arange(len(density)) - 0.5, density)
ax.xrange = [-0.5, len(density) - 0.5]
ax.set_ylabel("Particle count $n_i$")
ax.set_xlabel("Position $i$")
# Out:
# Text(0.5, 0, 'Position $i$')

# %% [markdown]
# Here, the total energy due to position 2 is $3 (3-1)=6$, and due to column 7 is $1 (1-1)=0$. We need to sum these to get the
# total energy.

# %% [markdown]
# ## Starting point
#
# Create a Python module:

# %%
# %%bash
# rm -rf diffusion
# mkdir diffusion
# install -m 644 /dev/null diffusion/__init__.py

# %% [markdown]
# **Windows:** You will need to run the following instead
#
# ```cmd
# %%cmd
# rmdir /s diffusion
# mkdir diffusion
# type nul > diffusion/__init__.py
# ```
#
# **NB.** If you are using the Windows command prompt, you will also have to replace all subsequent `%%bash` directives with `%%cmd`

# %% [markdown]
# * Implementation file: diffusion_model.py

# %%
# %%writefile diffusion/model.py
def energy(density, coeff=1.0):
    """Energy associated with the diffusion model

    Parameters
    ----------

    density: array of positive integers
        Number of particles at each position i in the array
    coeff: float
        Diffusion coefficient.
    """
    # implementation goes here
# Out:
# Writing diffusion/model.py

# %% [markdown]
# * Testing file: test_diffusion_model.py

# %%
# %%writefile diffusion/test_model.py
from .model import energy


def test_energy():
    """Optional description for nose reporting."""
    # Test something
# Out:
# Writing diffusion/test_model.py

# %% [markdown]
# Invoke the tests:

# %%
# %%bash
# cd diffusion
# py.test
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.9, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: /home/turingdev/rsd-engineering/rsd-engineeringcourse/ch03tests/diffusion
# plugins: cov-2.12.1, anyio-3.3.0
# collected 1 item
#
# test_model.py .                                                          [100%]
#
# ============================== 1 passed in 0.05s ===============================

# %% [markdown]
# Now, write your code (in `model.py`), and tests (in `test_model.py`), testing as you do.

# %% [markdown]
# ## Solution
#
# Don't look until after you've tried!
#
# In the spirit of test-driven development let's first consider our tests.

# %%
# %%writefile diffusion/test_model.py
"""Unit tests for a diffusion model."""

from pytest import raises
from .model import energy


def test_energy_fails_on_non_integer_density():
    with raises(TypeError) as exception:
        energy([1.0, 2, 3])


def test_energy_fails_on_negative_density():
    with raises(ValueError) as exception:
        energy([-1, 2, 3])


def test_energy_fails_ndimensional_density():
    with raises(ValueError) as exception:
        energy([[1, 2, 3], [3, 4, 5]])


def test_zero_energy_cases():
    # Zero energy at zero density
    densities = [[], [0], [0, 0, 0]]
    for density in densities:
        assert energy(density) == 0


def test_derivative():
    from numpy.random import randint

    # Loop over vectors of different sizes (but not empty)
    for vector_size in randint(1, 1000, size=30):

        # Create random density of size N
        density = randint(50, size=vector_size)

        # will do derivative at this index
        element_index = randint(vector_size)

        # modified densities
        density_plus_one = density.copy()
        density_plus_one[element_index] += 1

        # Compute and check result
        # d(n^2-1)/dn = 2n
        expected = 2.0 * density[element_index] if density[element_index] > 0 else 0
        actual = energy(density_plus_one) - energy(density)
        assert expected == actual


def test_derivative_no_self_energy():
    """If particle is alone, then its participation to energy is zero."""
    from numpy import array

    density = array([1, 0, 1, 10, 15, 0])
    density_plus_one = density.copy()
    density[1] += 1

    expected = 0
    actual = energy(density_plus_one) - energy(density)
    assert expected == actual
# Out:
# Overwriting diffusion/test_model.py

# %% [markdown]
# Now let's write an implementation that passes the tests.

# %%
# %%writefile diffusion/model.py
"""Simplistic 1-dimensional diffusion model."""
from numpy import array, any, sum


def energy(density):
    """Energy associated with the diffusion model
    :Parameters:
      density: array of positive integers
         Number of particles at each position i in the array/geometry
    """

    # Make sure input is an numpy array
    density = array(density)

    # ...of the right kind (integer). Unless it is zero length,
    #    in which case type does not matter.

    if density.dtype.kind != "i" and len(density) > 0:
        raise TypeError("Density should be a array of *integers*.")
    # and the right values (positive or null)
    if any(density < 0):
        raise ValueError("Density should be an array of *positive* integers.")
    if density.ndim != 1:
        raise ValueError(
            "Density should be an a *1-dimensional*" + "array of positive integers."
        )

    return sum(density * (density - 1))
# Out:
# Overwriting diffusion/model.py

# %%
# %%bash
# cd diffusion
# py.test
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.9, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: /home/turingdev/rsd-engineering/rsd-engineeringcourse/ch03tests/diffusion
# plugins: cov-2.12.1, anyio-3.3.0
# collected 6 items
#
# test_model.py ......                                                     [100%]
#
# ============================== 6 passed in 0.25s ===============================

# %% [markdown]
# ## Coverage
#
# With py.test, you can use the ["pytest-cov" plugin](https://github.com/pytest-dev/pytest-cov) to measure test coverage

# %%
# %%bash
# cd diffusion
# py.test --cov
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.9, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: /home/turingdev/rsd-engineering/rsd-engineeringcourse/ch03tests/diffusion
# plugins: cov-2.12.1, anyio-3.3.0
# collected 6 items
#
# test_model.py ......                                                     [100%]
#
# ---------- coverage: platform darwin, python 3.7.9-final-0 -----------
# Name                                                                                                                                     Stmts   Miss  Cover
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/_argcomplete.py                       37     36     3%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/_code/code.py                        697    681     2%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/_code/source.py                      142    140     1%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/_io/terminalwriter.py                112     66    41%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/_io/wcwidth.py                        25     16    36%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/assertion/__init__.py                 84     73    13%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/assertion/rewrite.py                 626    539    14%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/cacheprovider.py                     313    263    16%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/capture.py                           559    480    14%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/compat.py                            160    124    22%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/config/__init__.py                   804    690    14%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/config/argparsing.py                 252    207    18%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/debugging.py                         226    217     4%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/deprecated.py                         16     15     6%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/doctest.py                           351    341     3%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/faulthandler.py                       62     46    26%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/fixtures.py                          825    685    17%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/helpconfig.py                        132    122     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/junitxml.py                          373    371     1%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/logging.py                           401    293    27%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/main.py                              461    288    38%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/mark/__init__.py                     139    124    11%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/mark/structures.py                   241    224     7%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/monkeypatch.py                       170    157     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/nodes.py                             270    186    31%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/nose.py                               21     10    52%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/pastebin.py                           70     69     1%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/pathlib.py                           338    270    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/python.py                            841    632    25%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/python_api.py                        249    225    10%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/reports.py                           278    248    11%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/runner.py                            299    179    40%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/setuponly.py                          56     54     4%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/setupplan.py                          24     22     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/skipping.py                          176    144    18%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/stepwise.py                           68     67     1%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/store.py                              34     27    21%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/terminal.py                          895    693    23%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/tmpdir.py                            114     99    13%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/unittest.py                          243    234     4%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/_pytest/warnings.py                           63     44    30%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/anyio/pytest_plugin.py                       106     98     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/importlib_metadata/__init__.py               344    339     1%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/importlib_metadata/_compat.py                 18     17     6%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/__config__.py                           40     26    35%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/__init__.py                            142     46    68%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/_distributor_init.py                     0      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/_globals.py                             19      2    89%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/_pytesttester.py                        51     43    16%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/_version.py                              4      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/compat/__init__.py                       7      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/compat/_inspect.py                      67     17    75%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/compat/py3k.py                          59     25    58%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/__init__.py                        85     16    81%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_add_newdocs.py                   261      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_add_newdocs_scalars.py            48      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_asarray.py                        34     26    24%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_dtype.py                         157    137    13%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_dtype_ctypes.py                   54     36    33%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_exceptions.py                     96     57    41%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_internal.py                      426    328    23%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_methods.py                       155    116    25%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_string_helpers.py                 15      5    67%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_type_aliases.py                  122     13    89%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/_ufunc_config.py                   82     23    72%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/arrayprint.py                     545    435    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/defchararray.py                   410    243    41%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/einsumfunc.py                     408    385     6%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/fromnumeric.py                    353    199    44%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/function_base.py                  117     56    52%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/getlimits.py                      195     37    81%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/machar.py                         187    178     5%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/memmap.py                          91     73    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/multiarray.py                      99     22    78%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/numeric.py                        489    340    30%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/numerictypes.py                   143     66    54%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/overrides.py                       58      9    84%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/records.py                        355    310    13%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/shape_base.py                     186    148    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/core/umath.py                            4      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/ctypeslib.py                           211    175    17%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/fft/__init__.py                          8      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/fft/_pocketfft.py                      164    120    27%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/fft/helper.py                           46     33    28%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/__init__.py                         39      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/_datasource.py                     176    139    21%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/_iotools.py                        348    300    14%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/_version.py                         75     61    19%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/arraypad.py                        218    200     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/arraysetops.py                     197    167    15%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/arrayterator.py                     70     59    16%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/format.py                          267    235    12%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/function_base.py                  1139   1001    12%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/histograms.py                      287    254    11%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/index_tricks.py                    254    185    27%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/mixins.py                           59     12    80%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/nanfunctions.py                    279    219    22%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/npyio.py                           849    778     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/polynomial.py                      424    310    27%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/scimath.py                          61     38    38%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/shape_base.py                      251    205    18%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/stride_tricks.py                    90     70    22%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/twodim_base.py                     175    111    37%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/type_check.py                      129     90    30%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/ufunclike.py                        57     30    47%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/lib/utils.py                           455    416     9%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/linalg/__init__.py                       6      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/linalg/linalg.py                       670    507    24%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/ma/__init__.py                          10      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/ma/core.py                            2386   1773    26%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/ma/extras.py                           559    468    16%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/matrixlib/__init__.py                    5      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py                 233    178    24%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/__init__.py                  18      7    61%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/_polybase.py                401    296    26%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/chebyshev.py                357    294    18%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/hermite.py                  267    214    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/hermite_e.py                264    211    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/laguerre.py                 252    200    21%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/legendre.py                 261    209    20%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/polynomial.py               218    166    24%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/polynomial/polyutils.py                229    204    11%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/random/__init__.py                      17      1    94%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/random/_pickle.py                       22     12    45%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/numpy/version.py                               9      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pluggy/_tracing.py                            41     31    24%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pluggy/callers.py                            122     88    28%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pluggy/hooks.py                              175    101    42%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pluggy/manager.py                            195    153    22%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_builtin.py                               112     78    30%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_code/__init__.py                           0      0   100%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_code/code.py                             524    408    22%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_error.py                                  52     49     6%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_path/common.py                           278    228    18%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_path/local.py                            693    619    11%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/py/_vendored_packages/apipkg/__init__.py     151    132    13%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pytest_cov/compat.py                          19     15    21%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pytest_cov/embed.py                           80     74     8%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pytest_cov/engine.py                         221    200    10%
# /home/turingdev/.pyenv/versions/3.7.9/envs/rsd-engineeringcourse/lib/python3.7/site-packages/pytest_cov/plugin.py                         204    186     9%
# __init__.py                                                                                                                                  0      0   100%
# model.py                                                                                                                                    10      0   100%
# test_model.py                                                                                                                               33      0   100%
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# TOTAL                                                                                                                                    32701  25582    22%
#
#
# ============================== 6 passed in 3.68s ===============================

# %% [markdown]
# Or an html report:

# %%
# %%bash
# #%%cmd (windows)
# cd diffusion
# py.test --cov --cov-report html
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.9, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: /home/turingdev/rsd-engineering/rsd-engineeringcourse/ch03tests/diffusion
# plugins: cov-2.12.1, anyio-3.3.0
# collected 6 items
#
# test_model.py ......                                                     [100%]
#
# ---------- coverage: platform darwin, python 3.7.9-final-0 -----------
# Coverage HTML written to dir htmlcov
#
#
# ============================== 6 passed in 11.32s ==============================

# %% [markdown]
# Look at the [coverage results](diffusion/htmlcov/index.html)
