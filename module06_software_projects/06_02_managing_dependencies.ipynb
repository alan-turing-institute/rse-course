# %% [markdown]
# # Managing Dependencies

# %% [markdown]
# ## Specifying Dependencies
#
# ### requirements.txt
#
# ```
# geopy
# imageio
# matplotlib
# numpy
# requests
# ```
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ### Others
#
#
# ### Pinning versions
#
# ```
# geopy==2.2.0
# imageio==2.19.3
# matplotlib==3.5.2
# numpy==1.23.0
# requests==2.28.1
# ```
#
# ```bash
# pip freeze
# ```

# %%
! pip freeze
# Out:
# alabaster==0.7.12
# alembic @ file:///home/conda/feedstock_root/build_artifacts/alembic_1647367721563/work
# anyio @ file:///Users/runner/miniforge3/conda-bld/anyio_1652463928486/work/dist
# appdirs==1.4.4
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1649077682618/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1640817743617/work
# argon2-cffi-bindings @ file:///Users/runner/miniforge3/conda-bld/argon2-cffi-bindings_1649500366121/work
# astroid==2.8.6
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1618968359944/work
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1640799537051/work
# Babel==2.9.1
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1649463573192/work
# black==21.12b0
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1649361991009/work
# brotlipy @ file:///Users/runner/miniforge3/conda-bld/brotlipy_1648854211613/work
# certifi==2022.5.18.1
# cffi @ file:///Users/runner/miniforge3/conda-bld/cffi_1636046181956/work
# charset-normalizer @ file:///home/conda/feedstock_root/build_artifacts/charset-normalizer_1644853463426/work
# click==7.1.2
# colorama==0.4.4
# coverage==6.2
# cryptography @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_b470f7cb-c8f1-42c9-b84f-23789ea77e7c9difcqh4/croots/recipe/cryptography_1652101134392/work
# cycler==0.11.0
# Cython==0.29.24
# debugpy @ file:///Users/runner/miniforge3/conda-bld/debugpy_1649586394624/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# defusedxml @ file:///home/conda/feedstock_root/build_artifacts/defusedxml_1615232257335/work
# docutils==0.16
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1643888246732/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1646044401614/work
# fastjsonschema @ file:///home/conda/feedstock_root/build_artifacts/python-fastjsonschema_1641751198313/work/dist
# flake8==4.0.1
# flit_core @ file:///home/conda/feedstock_root/build_artifacts/flit-core_1645629044586/work/source/flit_core
# geographiclib==1.52
# geopy==2.2.0
# gitdb==4.0.9
# GitPython==3.1.26
# greenlet @ file:///Users/runner/miniforge3/conda-bld/greenlet_1648882429988/work
# h5py==3.5.0
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1642433548627/work
# imageio==2.10.1
# imagesize==1.3.0
# importlib-metadata @ file:///Users/runner/miniforge3/conda-bld/importlib-metadata_1648728334687/work
# importlib-resources @ file:///home/conda/feedstock_root/build_artifacts/importlib_resources_1652715758048/work
# iniconfig==1.1.1
# ipykernel @ file:///Users/runner/miniforge3/conda-bld/ipykernel_1649684317324/work/dist/ipykernel-6.13.0-py3-none-any.whl
# ipython==8.4.0
# ipython-genutils==0.2.0
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1647456365981/work
# isodate==0.6.1
# isort==5.10.1
# jarowinkler @ file:///Users/runner/miniforge3/conda-bld/jarowinkler_1650038640788/work
# jedi @ file:///Users/runner/miniforge3/conda-bld/jedi_1649067175439/work
# Jinja2==3.0.3
# joblib==1.1.0
# jsonschema==3.2.0
# jupyter-book==0.12.0
# jupyter-cache==0.4.3
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1652061014773/work
# jupyter-contrib-core==0.3.3
# jupyter-core @ file:///Users/runner/miniforge3/conda-bld/jupyter_core_1652365317930/work
# jupyter-nbextensions-configurator==0.4.1
# jupyter-server @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_1651092495905/work
# jupyter-server-mathjax==0.2.3
# jupyter-sphinx==0.3.2
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1649936611996/work
# jupyterlab-widgets @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_widgets_1647446862951/work
# jupytext==1.11.5
# kiwisolver==1.3.2
# latexcodec==2.0.1
# lazy-object-proxy==1.7.1
# line-profiler==3.3.1
# linkify-it-py==1.0.3
# llvmlite==0.38.1
# lxml==4.6.5
# Mako @ file:///home/conda/feedstock_root/build_artifacts/mako_1649097013621/work
# markdown-it-py==1.1.0
# MarkupSafe @ file:///Users/runner/miniforge3/conda-bld/markupsafe_1648737704633/work
# matplotlib==3.4.3
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1631080358261/work
# mccabe==0.6.1
# mdit-py-plugins==0.2.8
# mistune @ file:///Users/runner/miniforge3/conda-bld/mistune_1635844789148/work
# mypy==0.961
# mypy-extensions==0.4.3
# myst-nb==0.13.1
# myst-parser==0.15.2
# nbclient==0.5.13
# nbconvert @ file:///home/conda/feedstock_root/build_artifacts/nbconvert-meta_1649676641343/work
# nbdime==3.1.1
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1651607001005/work
# nbgrader @ file:///Users/runner/miniforge3/conda-bld/nbgrader_1651944341993/work
# nbqa==1.3.1
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1648959695634/work
# nose==1.3.7
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1650363291341/work
# numba==0.55.2
# numpy==1.22.4
# numpydoc==1.1.0
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1637239678211/work
# pandas==1.1.5
# pandocfilters @ file:///home/conda/feedstock_root/build_artifacts/pandocfilters_1631603243851/work
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1638334955874/work
# pathspec==0.9.0
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1602535608087/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow==9.0.0
# platformdirs==2.4.1
# pluggy==1.0.0
# ply==3.11
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1649447152425/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1649130487073/work
# psutil @ file:///Users/runner/miniforge3/conda-bld/psutil_1648873040820/work
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pure-eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1642875951954/work
# py==1.11.0
# pybtex==0.24.0
# pybtex-docutils==1.0.1
# pycodestyle==2.8.0
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1636257122734/work
# pydata-sphinx-theme==0.7.2
# pyee==8.2.2
# pyflakes==2.4.0
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1650904496387/work
# pylint==2.11.1
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1643496850550/work
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1652235407899/work
# pyppeteer==0.2.6
# PyQt5==5.12.3
# PyQt5_sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyrsistent @ file:///Users/runner/miniforge3/conda-bld/pyrsistent_1649013453068/work
# PySocks @ file:///Users/runner/miniforge3/conda-bld/pysocks_1648857336012/work
# pytest==7.1.2
# pytest-cov==3.0.0
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# pytz==2021.3
# PyYAML==6.0
# pyzmq @ file:///Users/runner/miniforge3/conda-bld/pyzmq_1652965439903/work
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole-base_1648505151387/work
# QtPy @ file:///home/conda/feedstock_root/build_artifacts/qtpy_1651524593465/work
# rapidfuzz @ file:///Users/runner/miniforge3/conda-bld/rapidfuzz_1650770486033/work
# rdflib==6.0.2
# requests==2.28.1
# scikit-learn==1.0.1
# scipy==1.6.1
# Send2Trash @ file:///home/conda/feedstock_root/build_artifacts/send2trash_1628511208346/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# smmap==5.0.0
# sniffio @ file:///Users/runner/miniforge3/conda-bld/sniffio_1648819227435/work
# snowballstemmer==2.2.0
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1638550740809/work
# Sphinx==4.4.0
# sphinx-book-theme==0.1.10
# sphinx-comments==0.0.3
# sphinx-copybutton==0.4.0
# sphinx-external-toc==0.2.3
# sphinx-jupyterbook-latex==0.4.6
# sphinx-multitoc-numbering==0.1.3
# sphinx-panels==0.6.0
# sphinx-thebe==0.1.2
# sphinx-togglebutton==0.2.3
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-bibtex==2.2.1
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# SQLAlchemy==1.4.39
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1644872665635/work
# terminado @ file:///Users/runner/miniforge3/conda-bld/terminado_1652790663188/work
# testpath==0.5.0
# threadpoolctl==3.0.0
# tinycss2 @ file:///home/conda/feedstock_root/build_artifacts/tinycss2_1637612658783/work
# tokenize-rt==4.2.1
# toml==0.10.2
# tomli==1.2.3
# tomlkit==0.11.1
# tornado @ file:///Users/runner/miniforge3/conda-bld/tornado_1648827305366/work
# tqdm==4.62.3
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1652735690480/work
# typing_extensions==4.0.1
# uc-micro-py==1.0.1
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1647489083693/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webcolors==1.11.1
# webencodings==0.5.1
# websocket-client @ file:///home/conda/feedstock_root/build_artifacts/websocket-client_1648562593984/work
# websockets==10.3
# widgetsnbextension @ file:///Users/runner/miniforge3/conda-bld/widgetsnbextension_1647446996424/work
# wrapt==1.13.3
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1649012893348/work

# %% [markdown]
# ## Virtual Environments
#
# ### venv
#
# https://packaging.python.org/en/latest/guides/installing-using-pip-and-virtual-environments

# %%
# %%bash
#
# python -m venv myenv
# Out:
# bin
# include
# lib
# pyvenv.cfg

# %%
# %%bash
#
# ls myenv/

# %%
# %%bash
#
# which python
# Out:
# /Users/jroberts/opt/anaconda3/envs/rse-course/bin/python

# %%
# %%bash
#
# source myenv/bin/activate
# which python
# Out:
# /Users/jroberts/GitHub/rse-course/module06_software_projects/myenv/bin/python

# %%
# %%bash
#
# source myenv/bin/activate
# pip install -r requirements.txt

# %%
# %%bash
# source myenv/bin/activate
#
# # work in the environment
#
# deactivate
#
# which python
# Out:
# /Users/jroberts/opt/anaconda3/envs/rse-course/bin/python

# %% [markdown]
# ### conda
#
# and environment.yml
#
# ```yaml
# name: myenv
#
# dependencies:
#   - python=3.9
#   - geopy=2.2.0
#   - imageio=2.19.3
#   - matplotlib=3.5.2
#   - numpy=1.23.0
#   - requests=2.28.1
# ```
#
# ```bash
# conda env create -f environment.yml
# ```
#
# ```bash
# conda activate myenv
#
# # work in the environment
#
# conda deactivate
# ```
#
#
# ### Docker
#
#
# ### Which to choose?
#
# others pyenv?, ?poetry?)
#
# - requirements.txt, environment.yml, ?pyproject.toml/poetry.lock?

# %% [markdown]
# ## Reproducibility
